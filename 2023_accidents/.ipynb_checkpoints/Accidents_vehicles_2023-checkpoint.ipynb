# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import folium
from folium.plugins import HeatMap

# %%
accidents_vehicles= pd.read_csv("/Users/dannaciendua/Documents/CodeOp/group_project/dataset_gruopp/2023translated_content_accidents_vehicles.csv")

# %%
accidents_vehicles
# Out:
#            Case_Number  District_Code District_Name  Neighborhood_Code  \
# 0      2023S000536                 -1       Unknown                 -1
# 1      2023S000506                 -1       Unknown                 -1
# 2      2023S000506                 -1       Unknown                 -1
# 3      2023S001678                 -1       Unknown                 -1
# 4      2023S002486                 -1       Unknown                 -1
# ...                ...            ...           ...                ...
# 14356  2023S003149                 10    Sant Martí                 73
# 14357  2023S000552                 10    Sant Martí                 73
# 14358  2023S000552                 10    Sant Martí                 73
# 14359  2023S001127                 10    Sant Martí                 73
# 14360  2023S001127                 10    Sant Martí                 73
#
#          Neighborhood_Name  Street_Code  \
# 0                  Unknown           -1
# 1                  Unknown           -1
# 2                  Unknown           -1
# 3                  Unknown           -1
# 4                  Unknown           -1
# ...                    ...          ...
# 14356  la Verneda i la Pau       357602
# 14357  la Verneda i la Pau       357602
# 14358  la Verneda i la Pau       357602
# 14359  la Verneda i la Pau       700024
# 14360  la Verneda i la Pau       700024
#
#                                              Street_Name Postal_Code  \
# 0      Motors / Acer                                 ...         NaN
# 1      Motors                                        ...  152-154
# 2                                                    NaN         NaN
# 3      Corts / Arístides Maillol                     ...         NaN
# 4      Glòries Catalanes                             ...  1
# ...                                                  ...         ...
# 14356                                            Verneda  0049U0049U
# 14357                                            Verneda   0081 0081
# 14358                                            Verneda   0081 0081
# 14359                                        Josep Miret   0014 0014
# 14360                                        Josep Miret   0014 0014
#
#       Day_of_Week  Year  ...             Vehicle_Type_Description  \
# 0        Thursday  2023  ...                                  Car
# 1        Thursday  2023  ...                           Motorcycle
# 2        Thursday  2023  ...                                  Car
# 3        Thursday  2023  ...                                  Bus
# 4        Thursday  2023  ...                      Articulated bus
# ...           ...   ...  ...                                  ...
# 14356      Friday  2023  ...                        Tractor truck
# 14357    Saturday  2023  ...                                  Car
# 14358    Saturday  2023  ...  Motorized personal mobility vehicle
# 14359      Friday  2023  ...                           Motorcycle
# 14360      Friday  2023  ...                                  Car
#
#       Vehicle_Model_Description  Vehicle_Brand_Description  \
# 0                         ASTRA                       OPEL
# 1                        FSH125                      HONDA
# 2                         XCEED                        KIA
# 3                 LION'S CITY G                        MAN
# 4                    HYBRID H18                    SOLARIS
# ...                         ...                        ...
# 14356                   Unknown                 IVECO FIAT
# 14357                                         ES DESCONEIX
# 14358                        XS                      JOYOR
# 14359               LIBERTY 125                    PIAGGIO
# 14360                     SCALA                      SKODA
#
#        Vehicle_Color_Description License_Description License_Age  \
# 0                        granate             Unknown     Unknown
# 1                           Gray                   B          11
# 2                          White                   B          39
# 3                            Red                   D          17
# 4                            Red                 E D          26
# ...                          ...                 ...         ...
# 14356                      White                 E C           4
# 14357                      White             Unknown     Unknown
# 14358                      Black             Unknown     Unknown
# 14359                      Black                   B          12
# 14360                       Gray             Unknown     Unknown
#
#       UTM_X_Coordinate UTM_Y_Coordinate    Longitude      Latitude
# 0           428118.93        4578054.77  2.139637367  41.348935697
# 1           428888.97        4578390.79  2.148801757  41.352030518
# 2           428888.97        4578390.79  2.148801757  41.352030518
# 3           426626.85        4581292.09  2.121411776  41.377958412
# 4           432052.4         4583910.53  2.185995092  41.402018695
# ...                ...              ...          ...           ...
# 14356       433009.31        4586838.4   2.197117433  41.428469538
# 14357       433722.46        4586795.27  2.205656494  41.428140273
# 14358       433722.46        4586795.27  2.205656494  41.428140273
# 14359       433222.36        4586200.55  2.199737507  41.422742361
# 14360       433222.36        4586200.55  2.199737507  41.422742361
#
# [14361 rows x 26 columns]

# %% [markdown]
# ### Create a dictionary with the translations needed from catalan to english

# %%
file_path = "/Users/dannaciendua/Documents/CodeOp/group_project/dataset_gruopp/2023translated_content_accidents_vehicles.csv"
accidents_vehicles = pd.read_csv(file_path)

translation_dict = {
    
    "Conductor": "Driver", 'Vianant': 'Pedestrian', 'Passatger': 'Passenger', 'En pas regulat per semŕfor': 'In crossing regulated by traffic lights',
    "Dilluns": "Monday", "Dimarts": "Tuesday", "Dimecres": "Wednesday",
    "Dijous": "Thursday", "Divendres": "Friday", "Dissabte": "Saturday", "Diumenge": "Sunday",
    "Gener": "January", "Febrer": "February", "Març": "March", "Abril": "April",
    "Maig": "May", "Juny": "June", "Juliol": "July", "Agost": "August",
    "Setembre": "September", "Octubre": "October", "Novembre": "November", "Desembre": "December",
    "Il.lčs": "Uninjured",
     "No és causa del vianant": "Not caused by the pedestrian",
    "Creuar per fora pas de vianants": "Crossing outside the pedestrian crossing",
    "Transitar a peu per la calçada": "Walking on the road",
    "Desobeir el senyal del semàfor": "Disobeying the traffic light signal",
    "Altres": "Others",
    "Desobeir altres senyals": "Disobeying other signals",
    "Es desconeix": "Unknown", "Desconegut": "Unknown", "Altres": "Others",
    "Taxi": "Taxi", "Turisme": "Car", "Motocicleta": "Motorcycle",  "Autobús articulat": "Articulated bus",
    "Bicicleta": "Bicycle",
    "Veh. mobilitat personal amb motor": "Motorized personal mobility vehicle",
    "Camió rígid <= 3,5 tones": "Rigid truck <= 3.5 tons",
    "Furgoneta": "Van",
    "Ciclomotor": "Moped",
    "Tot terreny": "All-terrain vehicle",
    "Maquinària d'obres i serveis": "Construction and service machinery",
    "Camió rígid > 3,5 tones": "Rigid truck > 3.5 tons",
    "Taxi": "Taxi",
    "Ambulància": "Ambulance",
    "Tricicle": "Tricycle",
    "Unknown": "Unknown",
    "Autocaravana": "Motorhome",
    "Autocar": "Coach",
    "Tractor camió": "Tractor truck",
    "Altres vehicles amb motor": "Other motorized vehicles",
    "Veh. mobilitat personal sense motor": "Non-motorized personal mobility vehicle",
    "Pick-up": "Pick-up",
    "Quadricicle < 75 cc": "Quadricycle < 75 cc",
    "Altres vehicles sense motor": "Other non-motorized vehicles",
    "Tren o tramvia": "Train or tram",
    "Quadricicle > 75 cc": "Quadricycle > 75 cc", 'Blau': 'Blue',
    'Taronja': 'Orange',
    'Marró': 'Brown',
    'Verd': 'Green',
    'Negre/Groc': 'Black/Yellow',
    'Daurat': 'Golden',
    'Platejat': 'Silver',
    'Violeta': 'Violet',
    'Groc': 'Yellow',
    'Beige': 'Beige',
    'Rosa': 'Pink'
}

accidents_vehicles.replace(translation_dict, inplace=True)

output_path = "/Users/dannaciendua/Documents/CodeOp/group_project/dataset_gruopp/2023translated_content_accidents_vehicles.csv"
accidents_vehicles.to_csv(output_path, index=False)
print(f"Translated dataset saved to {output_path}")
# Out:
# Translated dataset saved to /Users/dannaciendua/Documents/CodeOp/group_project/dataset_gruopp/2023translated_content_accidents_vehicles.csv

# %% [markdown]
# ### Check the table, what I need and what I dont need, understand the information I have

# %%
accidents_vehicles.head()
# Out:
#        Case_Number  District_Code District_Name  Neighborhood_Code  \
# 0  2023S000536                 -1       Unknown                 -1
# 1  2023S000506                 -1       Unknown                 -1
# 2  2023S000506                 -1       Unknown                 -1
# 3  2023S001678                 -1       Unknown                 -1
# 4  2023S002486                 -1       Unknown                 -1
#
#   Neighborhood_Name  Street_Code  \
# 0           Unknown           -1
# 1           Unknown           -1
# 2           Unknown           -1
# 3           Unknown           -1
# 4           Unknown           -1
#
#                                          Street_Name Postal_Code Day_of_Week  \
# 0  Motors / Acer                                 ...         NaN    Thursday
# 1  Motors                                        ...  152-154       Thursday
# 2                                                NaN         NaN    Thursday
# 3  Corts / Arístides Maillol                     ...         NaN    Thursday
# 4  Glòries Catalanes                             ...  1             Thursday
#
#    Year  ...  Vehicle_Type_Description Vehicle_Model_Description  \
# 0  2023  ...                       Car                     ASTRA
# 1  2023  ...                Motorcycle                    FSH125
# 2  2023  ...                       Car                     XCEED
# 3  2023  ...                       Bus             LION'S CITY G
# 4  2023  ...           Articulated bus                HYBRID H18
#
#    Vehicle_Brand_Description  Vehicle_Color_Description License_Description  \
# 0                       OPEL                    granate             Unknown
# 1                      HONDA                       Gray                   B
# 2                        KIA                      White                   B
# 3                        MAN                        Red                   D
# 4                    SOLARIS                        Red                 E D
#
#   License_Age UTM_X_Coordinate UTM_Y_Coordinate    Longitude      Latitude
# 0     Unknown       428118.93        4578054.77  2.139637367  41.348935697
# 1          11       428888.97        4578390.79  2.148801757  41.352030518
# 2          39       428888.97        4578390.79  2.148801757  41.352030518
# 3          17       426626.85        4581292.09  2.121411776  41.377958412
# 4          26       432052.4         4583910.53  2.185995092  41.402018695
#
# [5 rows x 26 columns]

# %%
accidents_vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14361 entries, 0 to 14360
# Data columns (total 26 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Case_Number                   14357 non-null  object
#  1   District_Code                 14361 non-null  int64
#  2   District_Name                 14361 non-null  object
#  3   Neighborhood_Code             14361 non-null  int64
#  4   Neighborhood_Name             14361 non-null  object
#  5   Street_Code                   14361 non-null  int64
#  6   Street_Name                   14290 non-null  object
#  7   Postal_Code                   14257 non-null  object
#  8   Day_of_Week                   14361 non-null  object
#  9   Year                          14361 non-null  int64
#  10  Month_Code                    14361 non-null  int64
#  11  Month_Name                    14361 non-null  object
#  12  Day_of_Month                  14361 non-null  int64
#  13  Hour_of_Day                   14361 non-null  int64
#  14  Shift_Description             14361 non-null  object
#  15  Pedestrian_Cause_Description  14361 non-null  object
#  16  Vehicle_Type_Description      14357 non-null  object
#  17  Vehicle_Model_Description     14357 non-null  object
#  18  Vehicle_Brand_Description     14357 non-null  object
#  19  Vehicle_Color_Description     14357 non-null  object
#  20  License_Description           14357 non-null  object
#  21  License_Age                   14357 non-null  object
#  22  UTM_X_Coordinate              14361 non-null  object
#  23  UTM_Y_Coordinate              14361 non-null  object
#  24  Longitude                     14361 non-null  object
#  25  Latitude                      14361 non-null  object
# dtypes: int64(7), object(19)
# memory usage: 2.8+ MB

# %% [markdown]
# ### Drop columns that I dont need

# %%
columns_to_drop = ['District_Code', 'Neighborhood_Code', 'Street_Code', 'Postal_Code']
columns_existing = [col for col in columns_to_drop if col in accidents_vehicles.columns]
accidents_vehicles = accidents_vehicles.drop(columns=columns_existing, inplace=False)


print(accidents_vehicles.head())
# Out:
#        Case_Number District_Name Neighborhood_Name  \
# 0  2023S000536           Unknown           Unknown
# 1  2023S000506           Unknown           Unknown
# 2  2023S000506           Unknown           Unknown
# 3  2023S001678           Unknown           Unknown
# 4  2023S002486           Unknown           Unknown
#
#                                          Street_Name Day_of_Week  Year  \
# 0  Motors / Acer                                 ...    Thursday  2023
# 1  Motors                                        ...    Thursday  2023
# 2                                                NaN    Thursday  2023
# 3  Corts / Arístides Maillol                     ...    Thursday  2023
# 4  Glòries Catalanes                             ...    Thursday  2023
#
#    Month_Code Month_Name  Day_of_Month  Hour_of_Day  ...  \
# 0           1    January            26           14  ...
# 1           1    January            26           15  ...
# 2           1    January            26           15  ...
# 3           3      March            23           14  ...
# 4           4      April            27           20  ...
#
#   Vehicle_Type_Description Vehicle_Model_Description  \
# 0                      Car                     ASTRA
# 1               Motorcycle                    FSH125
# 2                      Car                     XCEED
# 3                      Bus             LION'S CITY G
# 4          Articulated bus                HYBRID H18
#
#   Vehicle_Brand_Description Vehicle_Color_Description License_Description  \
# 0                      OPEL                   granate             Unknown
# 1                     HONDA                      Gray                   B
# 2                       KIA                     White                   B
# 3                       MAN                       Red                   D
# 4                   SOLARIS                       Red                 E D
#
#   License_Age UTM_X_Coordinate UTM_Y_Coordinate    Longitude      Latitude
# 0     Unknown       428118.93        4578054.77  2.139637367  41.348935697
# 1          11       428888.97        4578390.79  2.148801757  41.352030518
# 2          39       428888.97        4578390.79  2.148801757  41.352030518
# 3          17       426626.85        4581292.09  2.121411776  41.377958412
# 4          26       432052.4         4583910.53  2.185995092  41.402018695
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Check for null values and sum them

# %%
accidents_vehicles.isnull().sum()
# Out:
# Case_Number                      4
# District_Name                    0
# Neighborhood_Name                0
# Street_Name                     71
# Day_of_Week                      0
# Year                             0
# Month_Code                       0
# Month_Name                       0
# Day_of_Month                     0
# Hour_of_Day                      0
# Shift_Description                0
# Pedestrian_Cause_Description     0
# Vehicle_Type_Description         4
# Vehicle_Model_Description        4
# Vehicle_Brand_Description        4
# Vehicle_Color_Description        4
# License_Description              4
# License_Age                      4
# UTM_X_Coordinate                 0
# UTM_Y_Coordinate                 0
# Longitude                        0
# Latitude                         0
# dtype: int64

# %% [markdown]
# ### Drop nan values and duplicates

# %%
accidents_vehicles = accidents_vehicles.dropna()

# %%
accidents_vehicles = accidents_vehicles.drop_duplicates()

# %% [markdown]
# ### Create new column with datetime

# %%
accidents_vehicles['datetime'] = pd.to_datetime({
    'year': accidents_vehicles['Year'],
    'month': accidents_vehicles['Month_Code'],
    'day': accidents_vehicles['Day_of_Month']
}) + pd.to_timedelta(accidents_vehicles['Hour_of_Day'], unit='h')

print(accidents_vehicles[['datetime']].head())
# Out:
#              datetime
# 0 2023-01-26 14:00:00
# 1 2023-01-26 15:00:00
# 3 2023-03-23 14:00:00
# 4 2023-04-27 20:00:00
# 6 2023-05-11 18:00:00

# %% [markdown]
# ### Re-check the table

# %%
accidents_vehicles.head()
# Out:
#        Case_Number District_Name Neighborhood_Name  \
# 0  2023S000536           Unknown           Unknown
# 1  2023S000506           Unknown           Unknown
# 3  2023S001678           Unknown           Unknown
# 4  2023S002486           Unknown           Unknown
# 6  2023S002816           Unknown           Unknown
#
#                                          Street_Name Day_of_Week  Year  \
# 0  Motors / Acer                                 ...    Thursday  2023
# 1  Motors                                        ...    Thursday  2023
# 3  Corts / Arístides Maillol                     ...    Thursday  2023
# 4  Glòries Catalanes                             ...    Thursday  2023
# 6  Motors                                        ...    Thursday  2023
#
#    Month_Code Month_Name  Day_of_Month  Hour_of_Day  ...  \
# 0           1    January            26           14  ...
# 1           1    January            26           15  ...
# 3           3      March            23           14  ...
# 4           4      April            27           20  ...
# 6           5        May            11           18  ...
#
#   Vehicle_Model_Description Vehicle_Brand_Description  \
# 0                     ASTRA                      OPEL
# 1                    FSH125                     HONDA
# 3             LION'S CITY G                       MAN
# 4                HYBRID H18                   SOLARIS
# 6                    SH 300                     HONDA
#
#   Vehicle_Color_Description License_Description License_Age UTM_X_Coordinate  \
# 0                   granate             Unknown     Unknown       428118.93
# 1                      Gray                   B          11       428888.97
# 3                       Red                   D          17       426626.85
# 4                       Red                 E D          26       432052.4
# 6                     Black                   A          12       427994.28
#
#   UTM_Y_Coordinate    Longitude      Latitude            datetime
# 0       4578054.77  2.139637367  41.348935697 2023-01-26 14:00:00
# 1       4578390.79  2.148801757  41.352030518 2023-01-26 15:00:00
# 3       4581292.09  2.121411776  41.377958412 2023-03-23 14:00:00
# 4       4583910.53  2.185995092  41.402018695 2023-04-27 20:00:00
# 6       4577969.06  2.138157684  41.348152595 2023-05-11 18:00:00
#
# [5 rows x 23 columns]

# %% [markdown]
# ### Re-check vehicle color is in english

# %%
accidents_vehicles['Vehicle_Color_Description'].unique()
# Out:
# array(['granate', 'Gray', 'Red', 'Black', 'White', 'Unknown', 'Others',
#        'Blue', 'Orange', 'Brown', 'Green', 'Black/Yellow', 'Golden',
#        'Silver', 'Violet', 'Yellow', 'Beige', 'Pink'], dtype=object)

# %% [markdown]
# ### Check for the unique values in the table

# %%
for column in accidents_vehicles.columns:
    unique_values = accidents_vehicles[column].unique()
    print(f"Unique values in column '{column}':")
    print(unique_values)
    print("-" * 50)
# Out:
# Unique values in column 'Case_Number':
# ['2023S000536    ' '2023S000506    ' '2023S001678    ' ...
#  '2023S003149    ' '2023S000552    ' '2023S001127    ']
# --------------------------------------------------
# Unique values in column 'District_Name':
# ['Unknown' 'Ciutat Vella' 'Eixample' 'Sants-Montjuïc' 'Les Corts'
#  'Sarrià-Sant Gervasi' 'Gràcia' 'Horta-Guinardó' 'Nou Barris'
#  'Sant Andreu' 'Sant Martí']
# --------------------------------------------------
# Unique values in column 'Neighborhood_Name':
# ['Unknown' 'el Raval' 'el Barri Gòtic' 'la Barceloneta'
#  'Sant Pere, Santa Caterina i la Ribera' 'el Fort Pienc'
#  'la Sagrada Família' "la Dreta de l'Eixample"
#  "l'Antiga Esquerra de l'Eixample" "la Nova Esquerra de l'Eixample"
#  'Sant Antoni' 'el Poble-sec' 'la Marina del Prat Vermell'
#  'la Marina de Port' 'la Font de la Guatlla' 'Hostafrancs' 'la Bordeta'
#  'Sants - Badal' 'Sants' 'les Corts' 'la Maternitat i Sant Ramon'
#  'Pedralbes' 'Vallvidrera, el Tibidabo i les Planes' 'Sarrià'
#  'les Tres Torres' 'Sant Gervasi - la Bonanova' 'Sant Gervasi - Galvany'
#  'el Putxet i el Farró' 'Vallcarca i els Penitents' 'el Coll' 'la Salut'
#  'la Vila de Gràcia' "el Camp d'en Grassot i Gràcia Nova"
#  'el Baix Guinardó' 'Can Baró' 'el Guinardó' "la Font d'en Fargues"
#  'el Carmel' 'la Teixonera' 'Sant Genís dels Agudells' 'Montbau'
#  "la Vall d'Hebron" 'la Clota' 'Horta' 'Vilapicina i la Torre Llobeta'
#  'Porta' 'el Turó de la Peira' 'Can Peguera' 'la Guineueta' 'Canyelles'
#  'les Roquetes' 'Verdun' 'la Prosperitat' 'la Trinitat Nova' 'Torre Baró'
#  'Ciutat Meridiana' 'Vallbona' 'la Trinitat Vella' 'Baró de Viver'
#  'el Bon Pastor' 'Sant Andreu' 'la Sagrera' 'el Congrés i els Indians'
#  'Navas' "el Camp de l'Arpa del Clot" 'el Clot'
#  'el Parc i la Llacuna del Poblenou' 'la Vila Olímpica del Poblenou'
#  'el Poblenou' 'Diagonal Mar i el Front Marítim del Poblenou'
#  'el Besòs i el Maresme' 'Provençals del Poblenou'
#  'Sant Martí de Provençals' 'la Verneda i la Pau']
# --------------------------------------------------
# Unique values in column 'Street_Name':
# ['Motors / Acer                                     '
#  'Motors                                            '
#  'Corts / Arístides Maillol                         ' ... 'Trajana'
#  'Verneda' 'Josep Miret']
# --------------------------------------------------
# Unique values in column 'Day_of_Week':
# ['Thursday' 'Monday' 'Tuesday' 'Wednesday' 'Saturday' 'Sunday' 'Friday']
# --------------------------------------------------
# Unique values in column 'Year':
# [2023]
# --------------------------------------------------
# Unique values in column 'Month_Code':
# [ 1  3  4  5  6  8  9 10 11 12  2  7]
# --------------------------------------------------
# Unique values in column 'Month_Name':
# ['January' 'March' 'April' 'May' 'June' 'August' 'September' 'October'
#  'November' 'December' 'February' 'July']
# --------------------------------------------------
# Unique values in column 'Day_of_Month':
# [26 23 27 11 25  4  1 29 10 28  7 19  2  9 17 22  8 24 20 18 12 14 13  5
#   3 31 21 15 16 30  6]
# --------------------------------------------------
# Unique values in column 'Hour_of_Day':
# [14 15 20 18  1  8 11 16 13 21 12 23  9 22 19 17  5 10  6  7  3  0  2  4]
# --------------------------------------------------
# Unique values in column 'Shift_Description':
# ['Afternoon' 'Night' 'Morning']
# --------------------------------------------------
# Unique values in column 'Pedestrian_Cause_Description':
# ['No és causa del  vianant' 'Crossing outside the pedestrian crossing'
#  'Walking on the road' 'Disobeying the traffic light signal' 'Others'
#  'Disobeying other signals']
# --------------------------------------------------
# Unique values in column 'Vehicle_Type_Description':
# ['Car' 'Motorcycle' 'Bus' 'Articulated bus' 'Rigid truck <= 3.5 tons'
#  'Van' 'Motorized personal mobility vehicle' 'Moped' 'All-terrain vehicle'
#  'Bicycle' 'Construction and service machinery' 'Rigid truck > 3.5 tons'
#  'Ambulance' 'Taxi' 'Tricycle' 'Unknown' 'Motorhome' 'Coach'
#  'Tractor truck' 'Other motorized vehicles'
#  'Non-motorized personal mobility vehicle' 'Pick-up' 'Quadricycle < 75 cc'
#  'Other non-motorized vehicles' 'Train or tram' 'Quadricycle > 75 cc']
# --------------------------------------------------
# Unique values in column 'Vehicle_Model_Description':
# ['ASTRA' 'FSH125' "LION'S CITY G" ... 'NINJA ZX' 'GSX1300BK'
#  'X8 125 PREMIUM']
# --------------------------------------------------
# Unique values in column 'Vehicle_Brand_Description':
# ['OPEL' 'HONDA' 'MAN' 'SOLARIS' 'SYM' 'Unknown' 'ES DESCONEIX' 'FORD'
#  'NISSAN' 'RENAULT' 'BICING' 'NOGE' 'KYMCO' 'BROMPTON' 'PIAGGIO' 'BMW'
#  'MERCEDES' 'YAMAHA' 'PEUGEOT' 'KEEWAY' 'SUZUKI' 'EMCO' 'VOLKSWAGEN'
#  'FIAT' 'IRISBUS' 'ARB ARBUCIES' 'SKODA' 'SCANIA' 'KAWASAKI' 'KTM' 'VOLVO'
#  'IVECO BUS' 'IRIZAR' 'INDCAR' 'TOYOTA' 'MACBOR' 'MERCEDES-BENZ'
#  'BERGADANA' 'CAYVOL' 'XIAOMI' 'CARROCERA CASTROSUA SA' 'HARLEY-DAVIDSON'
#  'DACIA' 'SWAPFIETS' 'MEBAUTO' 'AUDI' 'ECOXTREM' 'BUCHER' 'CHEVROLET'
#  'SCUTUM' 'KIA' 'NIU' 'CITROEN' '--------' 'SILENCE' 'LEXUS' 'ASKOLL'
#  'MONDIAL' 'HYUNDAI' 'SEAT' 'MOTO GUZZI' 'LECAPITAINE' 'MOMA' 'RIDE'
#  'SMART' 'FORD-CNG-TECHNIK' 'JOYOR' 'MINI' 'LAND ROVER' 'SSANGYONG'
#  'LAMBRETTA' 'SWM' 'VOGE' 'VESPA' 'ROMU' 'TESLA' 'ROCKRIDER' 'URBAN FOX'
#  'ROLLS-ROYCE' 'TECNOVE FIBERGLASS' 'ROS-ROCA' 'EQUIPFRED' 'HUSQVARNA'
#  'AYATS' 'DAELIM' 'ZONTES' 'CARROZADOS TECAI' 'RIEJU' 'IRIZAR E-MOBILITY'
#  'TUCANO' 'BAOTIAN' 'KNAUS' 'PORSCHE' 'JAGUAR' 'APRILIA' 'SUBARU'
#  'FRUMECAR' 'FURCAR' 'SUBIELA' 'INDIAN MOTORCYCLE' 'GENERIC' 'BSA'
#  'DECATHLON' 'JEEP' 'BH' 'CONOR' 'BTWIN' 'TEMSA' 'VOLKSWAGEN V W' 'DAEWOO'
#  'MOTRON MOTORRAD' 'GOES' 'SEGWAY' 'DUCATI' 'TREK' 'TECNOVE SECURITY' 'MG'
#  'MAZDA' 'CORNELLA' 'SMARTGYRO' 'HORWIN' 'CUPRA' 'TRANSGRUAS' 'DUALTRON'
#  'ORBEA' 'BENELLI' 'MITSUBISHI' 'MAHINDRA' 'AUSA' 'GIANT' 'TRIUMPH' 'DS'
#  'TORROT' 'ECOOTER' 'KEMMEL' 'SUPER SOCO' 'ALFA ROMEO' 'SHERCO' 'DAHON'
#  'ROYAL ENFIELD' 'INFINITI' 'VELCA' 'VSETT' 'MITT' 'TALLERES PRAT RUSIÑOL'
#  'RECAPOL' 'ASKOL' 'UNVI' 'NUUK' 'MALAGUTI' 'BYD' 'RAVO' 'MASH' 'AGRIMAC'
#  'ZWEEL' 'FOIMA' 'CARROCERIAS SEVILLA' 'SERCAR' 'AIXAM' 'DAF-HERMANNS'
#  'DAIMLER CHRYSLER' 'E-MAX' 'BRETCHA' 'E-MTB' 'BARBANY' 'GILERA' 'ORCAL'
#  'AIYUMO' 'QUADRO' 'JAGUAR LAND ROVER LTD' 'GRAU' 'BRIXTON' 'MAXUS' 'ERKE'
#  'RAY ELECTRIC MOTORS' 'FLIEGL' 'MONTESA' 'WOTTAN' 'MICRO COMPACT CAR'
#  'CHUANL' 'MINIMOTORS' 'PROTEC FIRE' 'ZAGO AUTOMOTIVE' 'SUMCO'
#  'LA JUNQUERA' 'ITT BOX SOLUTIONS' 'TALLERES JOFRAUTO' 'VDL BOVA'
#  'HYOSUNG' 'CARROCERIAS SANCA' 'RIGUAL' 'SARTRUCK' 'CHRYSLER' 'LYNK&CO'
#  'ZERO MOTORCYCLES' 'IVECO FIAT' 'DFSK' 'SERVICAR'
#  'JAGUAR LAND ROVER LIMIT' 'CARROCERIAS CITY' 'EFUN' 'DENNIS'
#  'GEESINKNORBA' 'LINDE' 'STILL' 'LECAPITAINE INDUSTRIE' 'HANWAY'
#  'RODRIGUEZ LOPEZ AUTO' 'LIEBHERR' 'FERRARI' 'DODGE' 'FERROSITE'
#  'SORIBERICA' 'IMF' 'SCOMADI' 'SETRA' 'SANBEN' 'MV AGUSTA' 'SCATTOLINI'
#  'ALSTOM' 'SAAB' 'COOLTRA' 'ISUZU' 'SIN MARCA' 'MERCEDES-AMG' 'LANCIA'
#  'EQUIPDRAULIC' 'JEANJE' 'COLD CAR' 'PACTON' 'LVNENG' 'MASERATI'
#  'PALFINGER' 'EUROGRUAS' 'LIGIER' 'TERRADAS' 'KSR MOTO AUSTRIA' 'TGB'
#  'VECTRIX' 'V MOTO' 'PUJOL' 'BMW I' 'CARROSSERIES TOLOSA' 'VALLOR'
#  'HAIBIKE' 'SORTIMO' 'GSE' 'KAABO' 'CARSUR CARROZADOS SL' 'VECTIA'
#  'CAR-BUS.NET' 'BEULAS' 'URBAN ELECTRIC MOTORS' 'ACURA' 'DERBI' 'JAP'
#  'SEMICARFRAN SL' 'IGLUVAN' 'TESLA MOTORS' 'MONCAR EUROPA' 'YIBEN'
#  'CITADIS' 'KUGOO' 'ALPINE RENAULT' 'CAFRAN' 'CODETRANS' 'BIMOTA'
#  'GRISLEY' 'FARID INDUSTRIE' 'LAMBERET' 'IPV' 'LEONART']
# --------------------------------------------------
# Unique values in column 'Vehicle_Color_Description':
# ['granate' 'Gray' 'Red' 'Black' 'White' 'Unknown' 'Others' 'Blue' 'Orange'
#  'Brown' 'Green' 'Black/Yellow' 'Golden' 'Silver' 'Violet' 'Yellow'
#  'Beige' 'Pink']
# --------------------------------------------------
# Unique values in column 'License_Description':
# ['Unknown' 'B' 'D' 'E D' 'A' 'AM' 'A2' 'C' 'A1' 'D1' 'E C1' 'Llicència'
#  'C1' 'B1' 'BTP' 'Sense permís' 'E D1' 'E C' 'E B']
# --------------------------------------------------
# Unique values in column 'License_Age':
# ['Unknown' '11' '17' '26' '12' '14' '13' '3' '7' '16' '28' '2' '52' '22'
#  '10' '44' '19' '20' '59' '4' '40' '21' '35' '8' '9' '30' '31' '50' '23'
#  '32' '5' '15' '58' '1' '36' '18' '47' '34' '24' '6' '38' '29' '39' '37'
#  '49' '25' '33' '46' '42' '41' '48' '45' '57' '27' '55' '0' '43' '54' '53'
#  '60' '61' '62' '51' '56' '66' '63' '65' '67' '64' '72' '76']
# --------------------------------------------------
# Unique values in column 'UTM_X_Coordinate':
# ['428118.93 ' '428888.97 ' '426626.85 ' ... '433009.31 ' '433722.46 '
#  '433222.36 ']
# --------------------------------------------------
# Unique values in column 'UTM_Y_Coordinate':
# ['4578054.77' '4578390.79' '4581292.09' ... '4586838.4 ' '4586795.27'
#  '4586200.55']
# --------------------------------------------------
# Unique values in column 'Longitude':
# ['2.139637367' '2.148801757' '2.121411776' ... '2.197117433' '2.205656494'
#  '2.199737507']
# --------------------------------------------------
# Unique values in column 'Latitude':
# ['41.348935697' '41.352030518' '41.377958412' ... '41.428469538'
#  '41.428140273' '41.422742361']
# --------------------------------------------------
# Unique values in column 'datetime':
# <DatetimeArray>
# ['2023-01-26 14:00:00', '2023-01-26 15:00:00', '2023-03-23 14:00:00',
#  '2023-04-27 20:00:00', '2023-05-11 18:00:00', '2023-05-25 01:00:00',
#  '2023-05-04 14:00:00', '2023-06-01 08:00:00', '2023-06-29 08:00:00',
#  '2023-08-10 11:00:00',
#  ...
#  '2023-08-02 15:00:00', '2023-11-16 07:00:00', '2023-09-26 07:00:00',
#  '2023-08-22 08:00:00', '2023-05-16 12:00:00', '2023-01-28 16:00:00',
#  '2023-06-02 21:00:00', '2023-10-14 12:00:00', '2023-01-28 18:00:00',
#  '2023-02-24 21:00:00']
# Length: 4558, dtype: datetime64[ns]
# --------------------------------------------------

# %% [markdown]
# ### Check for the unique values in street name

# %%
accidents_vehicles['Street_Name'].unique()
# Out:
# array(['Motors / Acer                                     ',
#        'Motors                                            ',
#        'Corts / Arístides Maillol                         ', ...,
#        'Trajana', 'Verneda', 'Josep Miret'], dtype=object)

# %% [markdown]
# ### Delete empty spaces in street_name

# %%
accidents_vehicles['Street_Name'] = (
    accidents_vehicles['Street_Name']
    .str.strip()  
)

# %% [markdown]
# ### ...

# %%
accidents_vehicles
# Out:
# The history saving thread hit an unexpected error (OperationalError('attempt to write a readonly database')).History will not be written to the database.
#            Case_Number District_Name    Neighborhood_Name  \
# 0      2023S000536           Unknown              Unknown
# 1      2023S000506           Unknown              Unknown
# 3      2023S001678           Unknown              Unknown
# 4      2023S002486           Unknown              Unknown
# 6      2023S002816           Unknown              Unknown
# ...                ...           ...                  ...
# 14356  2023S003149        Sant Martí  la Verneda i la Pau
# 14357  2023S000552        Sant Martí  la Verneda i la Pau
# 14358  2023S000552        Sant Martí  la Verneda i la Pau
# 14359  2023S001127        Sant Martí  la Verneda i la Pau
# 14360  2023S001127        Sant Martí  la Verneda i la Pau
#
#                      Street_Name Day_of_Week  Year  Month_Code Month_Name  \
# 0                  Motors / Acer    Thursday  2023           1    January
# 1                         Motors    Thursday  2023           1    January
# 3      Corts / Arístides Maillol    Thursday  2023           3      March
# 4              Glòries Catalanes    Thursday  2023           4      April
# 6                         Motors    Thursday  2023           5        May
# ...                          ...         ...   ...         ...        ...
# 14356                    Verneda      Friday  2023           5        May
# 14357                    Verneda    Saturday  2023           1    January
# 14358                    Verneda    Saturday  2023           1    January
# 14359                Josep Miret      Friday  2023           2   February
# 14360                Josep Miret      Friday  2023           2   February
#
#        Day_of_Month  Hour_of_Day  ... Vehicle_Model_Description  \
# 0                26           14  ...                     ASTRA
# 1                26           15  ...                    FSH125
# 3                23           14  ...             LION'S CITY G
# 4                27           20  ...                HYBRID H18
# 6                11           18  ...                    SH 300
# ...             ...          ...  ...                       ...
# 14356            26           11  ...                   Unknown
# 14357            28           18  ...
# 14358            28           18  ...                        XS
# 14359            24           21  ...               LIBERTY 125
# 14360            24           21  ...                     SCALA
#
#       Vehicle_Brand_Description Vehicle_Color_Description License_Description  \
# 0                          OPEL                   granate             Unknown
# 1                         HONDA                      Gray                   B
# 3                           MAN                       Red                   D
# 4                       SOLARIS                       Red                 E D
# 6                         HONDA                     Black                   A
# ...                         ...                       ...                 ...
# 14356                IVECO FIAT                     White                 E C
# 14357              ES DESCONEIX                     White             Unknown
# 14358                     JOYOR                     Black             Unknown
# 14359                   PIAGGIO                     Black                   B
# 14360                     SKODA                      Gray             Unknown
#
#       License_Age UTM_X_Coordinate UTM_Y_Coordinate    Longitude  \
# 0         Unknown       428118.93        4578054.77  2.139637367
# 1              11       428888.97        4578390.79  2.148801757
# 3              17       426626.85        4581292.09  2.121411776
# 4              26       432052.4         4583910.53  2.185995092
# 6              12       427994.28        4577969.06  2.138157684
# ...           ...              ...              ...          ...
# 14356           4       433009.31        4586838.4   2.197117433
# 14357     Unknown       433722.46        4586795.27  2.205656494
# 14358     Unknown       433722.46        4586795.27  2.205656494
# 14359          12       433222.36        4586200.55  2.199737507
# 14360     Unknown       433222.36        4586200.55  2.199737507
#
#            Latitude            datetime
# 0      41.348935697 2023-01-26 14:00:00
# 1      41.352030518 2023-01-26 15:00:00
# 3      41.377958412 2023-03-23 14:00:00
# 4      41.402018695 2023-04-27 20:00:00
# 6      41.348152595 2023-05-11 18:00:00
# ...             ...                 ...
# 14356  41.428469538 2023-05-26 11:00:00
# 14357  41.428140273 2023-01-28 18:00:00
# 14358  41.428140273 2023-01-28 18:00:00
# 14359  41.422742361 2023-02-24 21:00:00
# 14360  41.422742361 2023-02-24 21:00:00
#
# [14286 rows x 23 columns]

# %%
unique_values = accidents_vehicles['Involved_Vehicle_Type'].value_counts()

print(unique_values)

# %% [markdown]
# ### Drop duplicates

# %%
accidents_vehicles = accidents_vehicles.drop_duplicates(subset='Case_Number', keep='first')

# %%
print(accidents_vehicles.dtypes)
# Out:
# Case_Number                     object
# District_Code                    int64
# District_Name                   object
# Neighborhood_Code                int64
# Neighborhood_Name               object
# Street_Code                      int64
# Street_Name                     object
# Postal_Code                     object
# Day_of_Week                     object
# Year                             int64
# Month_Code                       int64
# Month_Name                      object
# Day_of_Month                     int64
# Hour_of_Day                      int64
# Shift_Description               object
# Pedestrian_Cause_Description    object
# Vehicle_Type_Description        object
# Vehicle_Model_Description       object
# Vehicle_Brand_Description       object
# Vehicle_Color_Description       object
# License_Description             object
# License_Age                     object
# UTM_X_Coordinate                object
# UTM_Y_Coordinate                object
# Longitude                       object
# Latitude                        object
# dtype: object

# %% [markdown]
# ### Create datetime column

# %%
accidents_vehicles['datetime'] = pd.to_datetime({
    'year': accidents_vehicles['Year'],
    'month': accidents_vehicles['Month_Code'],
    'day': accidents_vehicles['Day_of_Month']
}) + pd.to_timedelta(accidents_vehicles['Hour_of_Day'], unit='h')

print(accidents_vehicles[['datetime']].head())
# Out:
#              datetime
# 0 2023-01-26 14:00:00
# 1 2023-01-26 15:00:00
# 3 2023-03-23 14:00:00
# 4 2023-04-27 20:00:00
# 6 2023-05-11 18:00:00

# %%
accidents_vehicles = accidents_vehicles.dropna(subset=['datetime'])

# %%
numeric_columns = ['License_Age', 'UTM_X_Coordinate', 'UTM_Y_Coordinate', 'Longitude', 'Latitude','Year', 'District_Code', 'Neighborhood_Code', 'Street_Code', 'Month_Code', 'Day_of_Month', 'Hour_of_Day']
for col in numeric_columns:
    accidents_vehicles[col] = pd.to_numeric(accidents_vehicles[col], errors='coerce')
accidents_vehicles_cleaned = accidents_vehicles.dropna(subset=numeric_columns)

# %%
numeric_columns = ['UTM_X_Coordinate', 'UTM_Y_Coordinate', 'License_Age']
for col in numeric_columns:
   
    if accidents_vehicles[col].dtype == 'object':
        accidents_vehicles[col] = accidents_vehicles[col].str.replace(',', '.').astype(float)

# %%
accidents_vehicles['License_Age'] = pd.to_numeric(accidents_vehicles['License_Age'], errors='coerce').astype('Int64')  
accidents_vehicles = accidents_vehicles.dropna(subset=['License_Age'])

# %% [markdown]
# ### Save the clean data

# %%
accidents_vehicles.to_csv("/Users/dannaciendua/Documents/CodeOp/group_project/dataset_gruopp/2023_accidents_vehicles_cleaned.csv", index=False)

# %% [markdown]
# # Visualizations

# %% [markdown]
# # Top color by day

# %%
color_by_day = accidents_vehicles.groupby(['Day_of_Week', 'Vehicle_Color_Description']).size().reset_index(name='Count')
top_color_by_day = color_by_day.loc[color_by_day.groupby('Day_of_Week')['Count'].idxmax()]
top_color_by_day = top_color_by_day.sort_values(by='Count', ascending=False)
plt.figure(figsize=(10, 6))
plt.bar(top_color_by_day['Day_of_Week'], top_color_by_day['Count'], color='lavender')
for i, row in top_color_by_day.iterrows():
    plt.text(row['Day_of_Week'], row['Count'] + 1, row['Vehicle_Color_Description'], ha='center', fontsize=10)
plt.title('Top Vehicle Color by Day of the Week (Descending Order)')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Vehicles')
plt.grid(axis='y')
plt.show()
print(top_color_by_day)
# Out:
#     Day_of_Week Vehicle_Color_Description  Count
# 0        Friday                     Black    569
# 112   Wednesday                     White    547
# 77     Thursday                     White    531
# 15       Monday                     Black    518
# 81      Tuesday                     Black    491
# 31     Saturday                     Black    386
# 48       Sunday                     Black    313

# %% [markdown]
# # Top 5 colors in general

# %%
top_5_colors = accidents_vehicles[accidents_vehicles['Vehicle_Color_Description'] != 'Unknown'][
    'Vehicle_Color_Description'].value_counts().head(5)

plt.figure(figsize=(10, 6))
top_5_colors.plot(kind='bar', color='thistle', edgecolor='black')
plt.title('Top 5 Vehicle Colors Overall (Excluding Unknown)')
plt.xlabel('Vehicle Color')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()
print("Top 5 Vehicle Colors Overall (Excluding Unknown):")
print(top_5_colors)
# Out:
# Top 5 Vehicle Colors Overall (Excluding Unknown):
# Vehicle_Color_Description
# Black    3304
# White    3177
# Gray     2389
# Red      1242
# Blue      678
# Name: count, dtype: int64

# %% [markdown]
# # Top vehicles involved in accidents

# %% [markdown]
# ### In general

# %%
vehicle_type_distribution = accidents_vehicles['Vehicle_Type_Description'].value_counts().head(5)
plt.figure(figsize=(12, 8))
vehicle_type_distribution.plot(kind='bar', color='lightsteelblue', edgecolor='black')
plt.title('Top Vehicle Types Involved in Accidents')
plt.xlabel('Vehicle Type')
plt.ylabel('Number of Vehicles Involved')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### By day

# %%
vehicle_by_day = accidents_vehicles.groupby(['Day_of_Week', 'Vehicle_Type_Description']).size().reset_index(name='Count')

top_vehicle_by_day = vehicle_by_day.loc[vehicle_by_day.groupby('Day_of_Week')['Count'].idxmax()]

days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
top_vehicle_by_day['Day_of_Week'] = pd.Categorical(top_vehicle_by_day['Day_of_Week'], categories=days_order, ordered=True)
top_vehicle_by_day = top_vehicle_by_day.sort_values('Day_of_Week')
plt.figure(figsize=(10, 6))
plt.bar(top_vehicle_by_day['Day_of_Week'], top_vehicle_by_day['Count'], color='pink', edgecolor='black')

for index, row in top_vehicle_by_day.iterrows():
    plt.text(row['Day_of_Week'], row['Count'] + 1, row['Vehicle_Type_Description'], ha='center', fontsize=9)

plt.title('Top Vehicle Type Involved in Accidents by Day of the Week')
plt.xlabel('Day of the Week')
plt.ylabel('Number of Accidents')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# ### By month

# %%
vehicle_type_by_month = accidents_vehicles.groupby(['Month_Name', 'Vehicle_Type_Description']).size().reset_index(name='Count')

top_vehicle_by_month = vehicle_type_by_month.loc[vehicle_type_by_month.groupby('Month_Name')['Count'].idxmax()]

plt.figure(figsize=(12, 8))
plt.bar(top_vehicle_by_month['Month_Name'], top_vehicle_by_month['Count'], color='lightblue')
for i, row in top_vehicle_by_month.iterrows():
    plt.text(row['Month_Name'], row['Count'] + 1, row['Vehicle_Type_Description'], ha='center', fontsize=10)
plt.title('Top Vehicle Type by Month')
plt.xlabel('Month')
plt.ylabel('Number of Vehicles')
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# # Vehicle Brands and Models

# %%
filtered_data = accidents_vehicles[
    (accidents_vehicles['Vehicle_Brand_Description'] != 'Unknown') &
    (accidents_vehicles['Vehicle_Model_Description'] != 'Unknown') &
    (accidents_vehicles['Vehicle_Brand_Description'] != 'ES DESCONEIX') &
    (accidents_vehicles['Vehicle_Model_Description'] != 'ES DESCONEIX')
]

brand_model_counts = filtered_data.groupby(['Vehicle_Brand_Description', 'Vehicle_Model_Description']).size().reset_index(name='Count')

top_10_brand_models = brand_model_counts.sort_values(by='Count', ascending=False).head(10)


plt.figure(figsize=(12, 8))
plt.barh(top_10_brand_models['Vehicle_Brand_Description'] + " " + top_10_brand_models['Vehicle_Model_Description'], 
         top_10_brand_models['Count'], 
        edgecolor='black')

sns.set_palette("pastel")
plt.title('Top 10 Vehicle Brands and Models Involved in Accidents')
plt.xlabel('Number of Vehicles')
plt.ylabel('Vehicle Brand and Model')
plt.gca().invert_yaxis()  # Invert y-axis for better readability
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # License Types

# %%
filtered_data = accidents_vehicles[(accidents_vehicles['License_Description'] != 'Unknown')]
license_type_counts = filtered_data['License_Description'].value_counts().head(5)

sns.set_palette("pastel")
plt.figure(figsize=(10, 6))
license_type_counts.plot(kind='bar', edgecolor='black')
plt.title('Proportion of Drivers with Each License Type')
plt.xlabel('License Type')
plt.ylabel('Number of Drivers')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # License Age Distribution

# %%
accidents_vehicles['License_Age'] = pd.to_numeric(accidents_vehicles['License_Age'], errors='coerce')

plt.figure(figsize=(10, 6))
accidents_vehicles['License_Age'].dropna().plot(kind='hist', bins=20, color='lightcoral', edgecolor='black', alpha=0.7)
plt.title('License Age Distribution (in Years)')
plt.xlabel('License Age (Years)')
plt.ylabel('Frequency')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# # License Age by vehicle

# %%
filtered_data = accidents_vehicles[(accidents_vehicles['Vehicle_Type_Description'] != 'Unknown')]
license_age_by_vehicle_type = (
    filtered_data.groupby('Vehicle_Type_Description')['License_Age']
    .mean()
    .dropna()
    .reset_index()
    .sort_values(by='License_Age', ascending=False).head(5)
)


plt.figure(figsize=(12, 6))
plt.bar(
    license_age_by_vehicle_type['Vehicle_Type_Description'], 
    license_age_by_vehicle_type['License_Age'], 
    color='lightgreen', edgecolor='black'
)
sns.set_palette("pastel")
plt.title('Average License Age by Vehicle Type')
plt.xlabel('Vehicle Type')
plt.ylabel('Average License Age (Years)')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# > 12420     return self._stat_function(
#   12421         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12422     )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/series.py:6457, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6453     raise TypeError(
#    6454         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6455         "with non-numeric dtypes."
#    6456     )
# -> 6457 return op(delegate, skipna=skipna, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string '' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 4
#       1 filtered_data = accidents_vehicles[(accidents_vehicles['Vehicle_Type_Description'] != 'Unknown')]
#       2 license_age_by_vehicle_type = (
#       3     filtered_data.groupby('Vehicle_Type_Description')['License_Age']
# ----> 4     .mean()
#       5     .dropna()
#       6     .reset_index()
#       7     .sort_values(by='License_Age', ascending=False).head(5)
#       8 )
#      11 plt.figure(figsize=(12, 6))
#      12 plt.bar(
#      13     license_age_by_vehicle_type['Vehicle_Type_Description'],
#      14     license_age_by_vehicle_type['License_Age'],
#      15     color='lightgreen', edgecolor='black'
#      16 )
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/internals/base.py:367, in SingleDataManager.grouped_reduce(self, func)
#     365 def grouped_reduce(self, func):
#     366     arr = self.array
# --> 367     res = func(arr)
#     368     index = default_index(len(res))
#     370     mgr = type(self).from_array(res, index)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/pandas/core/groupby/groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %% [markdown]
# # License Age Distribution by ranges

# %%
accidents_vehicles['License_Age'] = pd.to_numeric(accidents_vehicles['License_Age'], errors='coerce')
valid_license_age = accidents_vehicles['License_Age'].dropna()
bins = list(range(0, 101, 10))  # 0-10, 11-20, ..., 91-100
labels = [f"{b}-{b+9}" for b in bins[:-1]]  # Label bins as "0-9", "10-19", etc.
accidents_vehicles['License_Age_Binned'] = pd.cut(accidents_vehicles['License_Age'], bins=bins, labels=labels)
license_age_counts = accidents_vehicles['License_Age_Binned'].value_counts().sort_index()

plt.figure(figsize=(12, 8))
sns.barplot(x=license_age_counts.index, y=license_age_counts.values, palette="Blues")

plt.title('Accidents by License Age Groups', fontsize=16)
plt.xlabel('License Age Group (years)', fontsize=12)
plt.ylabel('Accident Count', fontsize=12)
plt.xticks(rotation=45, fontsize=10)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/2b/p_02_vw56dz2qcq7yt8y1xh40000gn/T/ipykernel_34482/2591703195.py:14: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=license_age_counts.index, y=license_age_counts.values, palette="Blues")
